# %%
#fit powerlaw, si ricavano i k con i loro errori a posteriori. 
#nome opportuno per i csv...
#acquisizione tutti i csv, ognuno con i gradi di ogni nodo
#creazione distribuzione di grado
#plot log
#fit lineare logY logX

# %%
distr1 <- read.csv(file="../../log/degree_distr2018_08_03_18_18_47.csv", skip=12, header=TRUE, sep=",") ## read file
distr2 <- read.csv(file="../../log/degree_distr2018_08_03_18_19_18.csv", skip=12, header=TRUE, sep=",") ## read file
distr3 <- read.csv(file="../../log/degree_distr2018_08_03_18_19_38.csv", skip=12, header=TRUE, sep=",") ## read file
distr4 <- read.csv(file="../../log/degree_distr2018_08_03_18_19_58.csv", skip=12, header=TRUE, sep=",") ## read file
distr5 <- read.csv(file="../../log/degree_distr2018_08_03_18_20_17.csv", skip=12, header=TRUE, sep=",") ## read file

distr6 <- read.csv(file="../../log/degree_distr2018_08_03_18_20_35.csv", skip=12, header=TRUE, sep=",") ## read file
distr7 <- read.csv(file="../../log/degree_distr2018_08_03_18_20_50.csv", skip=12, header=TRUE, sep=",") ## read file
distr8 <- read.csv(file="../../log/degree_distr2018_08_03_18_21_08.csv", skip=12, header=TRUE, sep=",") ## read file
distr9 <- read.csv(file="../../log/degree_distr2018_08_03_18_30_45.csv", skip=12, header=TRUE, sep=",") ## read file
distr10<- read.csv(file="../../log/degree_distr2018_08_03_18_30_58.csv", skip=12, header=TRUE, sep=",") ## read file

distr11<- read.csv(file="../../log/degree_distr2018_08_03_18_31_12.csv", skip=12, header=TRUE, sep=",") ## read file
distr12<- read.csv(file="../../log/degree_distr2018_08_03_18_31_41.csv", skip=12, header=TRUE, sep=",") ## read file
distr13<- read.csv(file="../../log/degree_distr2018_08_03_18_31_53.csv", skip=12, header=TRUE, sep=",") ## read file
distr14<- read.csv(file="../../log/degree_distr2018_08_03_18_32_05.csv", skip=12, header=TRUE, sep=",") ## read file
distr15<- read.csv(file="../../log/degree_distr2018_08_03_18_32_19.csv", skip=12, header=TRUE, sep=",") ## read file

distr16<- read.csv(file="../../log/degree_distr2018_08_03_18_32_35.csv", skip=12, header=TRUE, sep=",") ## read file
distr17<- read.csv(file="../../log/degree_distr2018_08_03_18_44_12.csv", skip=12, header=TRUE, sep=",") ## read file
distr18<- read.csv(file="../../log/degree_distr2018_08_03_18_44_28.csv", skip=12, header=TRUE, sep=",") ## read file
distr19<- read.csv(file="../../log/degree_distr2018_08_03_18_44_41.csv", skip=12, header=TRUE, sep=",") ## read file
distr20<- read.csv(file="../../log/degree_distr2018_08_03_18_44_56.csv", skip=12, header=TRUE, sep=",") ## read file

# %%
degrees <- distr1[,c("degree")]
eps<-0.01
X <- 1:(length(hist(degrees, breaks=20)$breaks) - 1)
Y <- hist(degrees, breaks=20)$counts + eps
X <- log(X)
Y <- log(Y + eps)
DATA = data.frame(X,Y)
linearMod <- lm(Y ~ X, data=DATA)  # build linear regression model on full data
print(linearMod)
print(summary(linearMod))
plot(DATA)
abline(linearMod)
k1<-linearMod$coefficients[2]
# Out:
# Call:
# lm(formula = Y ~ X, data = DATA)
#
# Coefficients:
# (Intercept)            X
#       8.692       -3.463
#
#
# Call:
# lm(formula = Y ~ X, data = DATA)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -3.956 -2.275  1.012  2.067  3.060
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   8.6923     1.4819   5.866 6.67e-06 ***
# X            -3.4630     0.6115  -5.663 1.08e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.436 on 22 degrees of freedom
# Multiple R-squared:  0.5931,	Adjusted R-squared:  0.5746
# F-statistic: 32.07 on 1 and 22 DF,  p-value: 1.077e-05
# Plot with title “Histogram of degrees”
# plot without title

# %%
degrees <- distr2[,c("degree")]
eps<-0.01
X <- 1:(length(hist(degrees, breaks=20)$breaks) - 1)
Y <- hist(degrees, breaks=20)$counts + eps
X <- log(X)
Y <- log(Y + eps)
DATA = data.frame(X,Y)
linearMod <- lm(Y ~ X, data=DATA)  # build linear regression model on full data
print(linearMod)
print(summary(linearMod))
plot(DATA)
abline(linearMod)
k2<-linearMod$coefficients[2]
# Out:
# Call:
# lm(formula = Y ~ X, data = DATA)
#
# Coefficients:
# (Intercept)            X
#       8.567       -3.251
#
#
# Call:
# lm(formula = Y ~ X, data = DATA)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.8223 -2.6993  0.9845  2.2112  2.6376
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)    8.567      1.550   5.527 2.07e-05 ***
# X             -3.251      0.661  -4.919 8.28e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.49 on 20 degrees of freedom
# Multiple R-squared:  0.5475,	Adjusted R-squared:  0.5248
# F-statistic:  24.2 on 1 and 20 DF,  p-value: 8.284e-05
# Plot with title “Histogram of degrees”
# plot without title

# %%
degrees <- distr3[,c("degree")]
eps<-0.01
X <- 1:(length(hist(degrees, breaks=20)$breaks) - 1)
Y <- hist(degrees, breaks=20)$counts + eps
X <- log(X)
Y <- log(Y + eps)
DATA = data.frame(X,Y)
linearMod <- lm(Y ~ X, data=DATA)  # build linear regression model on full data
print(linearMod)
print(summary(linearMod))
plot(DATA)
abline(linearMod)
k3<-linearMod$coefficients[2]
# Out:
# Call:
# lm(formula = Y ~ X, data = DATA)
#
# Coefficients:
# (Intercept)            X
#       7.397       -2.258
#
#
# Call:
# lm(formula = Y ~ X, data = DATA)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.5440 -0.6715  0.7041  0.9205  1.4029
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   7.3972     0.9073   8.153 8.68e-08 ***
# X            -2.2583     0.3869  -5.837 1.04e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.458 on 20 degrees of freedom
# Multiple R-squared:  0.6301,	Adjusted R-squared:  0.6116
# F-statistic: 34.07 on 1 and 20 DF,  p-value: 1.037e-05
# Plot with title “Histogram of degrees”
# plot without title

# %%
degrees <- distr4[,c("degree")]
eps<-0.01
X <- 1:(length(hist(degrees, breaks=20)$breaks) - 1)
Y <- hist(degrees, breaks=20)$counts + eps
X <- log(X)
Y <- log(Y + eps)
DATA = data.frame(X,Y)
linearMod <- lm(Y ~ X, data=DATA)  # build linear regression model on full data
print(linearMod)
print(summary(linearMod))
plot(DATA)
abline(linearMod)
k4<-linearMod$coefficients[2]
# Out:
# Call:
# lm(formula = Y ~ X, data = DATA)
#
# Coefficients:
# (Intercept)            X
#       8.911       -3.660
#
#
# Call:
# lm(formula = Y ~ X, data = DATA)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.9548 -1.7244 -0.4311  2.2154  3.3050
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   8.9108     1.3282   6.709 4.06e-07 ***
# X            -3.6600     0.5183  -7.062 1.69e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.274 on 26 degrees of freedom
# Multiple R-squared:  0.6573,	Adjusted R-squared:  0.6441
# F-statistic: 49.86 on 1 and 26 DF,  p-value: 1.69e-07
# Plot with title “Histogram of degrees”
# plot without title

# %%
degrees <- distr5[,c("degree")]
eps<-0.01
X <- 1:(length(hist(degrees, breaks=20)$breaks) - 1)
Y <- hist(degrees, breaks=20)$counts + eps
X <- log(X)
Y <- log(Y + eps)
DATA = data.frame(X,Y)
linearMod <- lm(Y ~ X, data=DATA)  # build linear regression model on full data
print(linearMod)
print(summary(linearMod))
plot(DATA)
abline(linearMod)
k5<-linearMod$coefficients[2]
# Out:
# Call:
# lm(formula = Y ~ X, data = DATA)
#
# Coefficients:
# (Intercept)            X
#       7.763       -2.490
#
#
# Call:
# lm(formula = Y ~ X, data = DATA)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.9773 -0.3484  0.3029  1.2484  1.6644
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   7.7626     0.9894   7.846 8.14e-08 ***
# X            -2.4902     0.4083  -6.099 3.87e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.626 on 22 degrees of freedom
# Multiple R-squared:  0.6284,	Adjusted R-squared:  0.6115
# F-statistic:  37.2 on 1 and 22 DF,  p-value: 3.872e-06
# Plot with title “Histogram of degrees”
# plot without title

# %%
degrees <- distr6[,c("degree")]
eps<-0.01
X <- 1:(length(hist(degrees, breaks=20)$breaks) - 1)
Y <- hist(degrees, breaks=20)$counts + eps
X <- log(X)
Y <- log(Y + eps)
DATA = data.frame(X,Y)
linearMod <- lm(Y ~ X, data=DATA)  # build linear regression model on full data
print(linearMod)
print(summary(linearMod))
plot(DATA)
abline(linearMod)
k6<-linearMod$coefficients[2]
# Out:
# Call:
# lm(formula = Y ~ X, data = DATA)
#
# Coefficients:
# (Intercept)            X
#       8.671       -3.487
#
#
# Call:
# lm(formula = Y ~ X, data = DATA)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.8665 -2.4557  0.9475  2.1194  2.9812
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   8.6707     1.5562   5.572 1.87e-05 ***
# X            -3.4874     0.6636  -5.255 3.83e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.5 on 20 degrees of freedom
# Multiple R-squared:   0.58,	Adjusted R-squared:  0.559
# F-statistic: 27.62 on 1 and 20 DF,  p-value: 3.833e-05
# Plot with title “Histogram of degrees”
# plot without title

# %%
k<-c(k1,k2,k3,k4,k5,k6)
mem<-1:6

END_DATA= data.frame(mem,k)
plot(mem,k, xlab="memory", ylab="k", panel.first=grid())
linearMod <- lm(k ~ mem, data=END_DATA)  # build linear regression model on full data
print(linearMod)
summary(linearMod)
# Out:
# Call:
# lm(formula = k ~ mem, data = END_DATA)
#
# Coefficients:
# (Intercept)          mem
#    -3.17772      0.02171
# Call:
# lm(formula = k ~ mem, data = END_DATA)
#
# Residuals:
#       1       2       3       4       5       6
# -0.3070 -0.1172  0.8543 -0.5692  0.5789 -0.4399
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -3.17772    0.60519  -5.251  0.00629 **
# mem          0.02171    0.15540   0.140  0.89563
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6501 on 4 degrees of freedom
# Multiple R-squared:  0.004857,	Adjusted R-squared:  -0.2439
# F-statistic: 0.01952 on 1 and 4 DF,  p-value: 0.8956
# plot without title
